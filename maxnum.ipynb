# %% [markdown]
# <a href="https://colab.research.google.com/github/Andilistics/cs1-python-diamond-balansag/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ask the user to enter three numbers
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

# Find the biggest number
if num1 >= num2 and num1 >= num3:
    biggest = num1
elif num2 >= num1 and num2 >= num3:
    biggest = num2
else:
    biggest = num3

# Show the result
print("The biggest number is:", biggest)
# Out:
# Enter the first number: 10
# Enter the second number: 43
# Enter the third number: 56
# The biggest number is: 56.0
